# %%
import gymnasium as gym
import numpy as np
from tqdm import tqdm
import torch
from torch import nn
from torch.optim import RMSprop, AdamW
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F

from stable_baselines3.common.vec_env import VecEnv

# %%
from functools import partial


class PolicyNet(nn.Module):
    def __init__(self, nvec_s: int, nvec_u: int, hidden_dim):
        super(PolicyNet, self).__init__()

        self.features_extractor = nn.Sequential(
            nn.Linear(nvec_s, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.Tanh(),
        )
        self.action_net = nn.Linear(hidden_dim, nvec_u)
        self.value_net = nn.Linear(hidden_dim, 1)

        module_gains = {
                self.features_extractor: np.sqrt(2),
                self.action_net: 0.01,
                self.value_net: 1,
            }
        def init_weights(module: nn.Module, gain: float = 1) -> None:
            """
            Orthogonal initialization (used in PPO and A2C)
            """
            if isinstance(module, (nn.Linear, nn.Conv2d)):
                nn.init.orthogonal_(module.weight, gain=gain)
                if module.bias is not None:
                    module.bias.data.fill_(0.0)

        for module, gain in module_gains.items():
                module.apply(partial(init_weights, gain=gain))


    def forward(self, x, deterministic = False):
        x = self.features_extractor(x)
        action_logits = self.action_net(x)
        value = self.value_net(x)
        dist = torch.distributions.Categorical(logits=action_logits)
        if deterministic:
            action = torch.argmax(action_logits)
            return action
        action = dist.sample()
        entropy = dist.entropy()
        log_prob = dist.log_prob(action)
        return value, action, log_prob, entropy
    
    def get_value(self, x):

        x = self.features_extractor(x)
        value = self.value_net(x)
        return value
    
    def evaluate_actions(self, states, actions):
        x = self.features_extractor(states)
        action_logits = self.action_net(x)
        dist = torch.distributions.Categorical(logits=action_logits)
        log_prob = dist.log_prob(actions)
        entropy = dist.entropy()
        values = self.value_net(x)
        return values, log_prob, entropy

# %%
class RolloutBuffer:

    def __init__(self, env:VecEnv, capacity, gamma, gae_lambda, device:torch.device, num_envs):
        self.env = env
        self.gamma = gamma
        self.gae_lambda = gae_lambda

        self.position = 0
        self.size = 0
        self.capacity = capacity

        self.n_actions = env.action_space.n 

        if isinstance(env.observation_space, gym.spaces.Box):
         self.n_states = env.observation_space.shape[0]
        elif isinstance(env.observation_space, gym.spaces.Discrete):
            self.n_states = 1

        self.states = np.zeros((capacity,num_envs, self.n_states), dtype=np.float32)
        self.actions = np.zeros((capacity,num_envs), dtype=np.float32)
        self.rewards = np.zeros((capacity,num_envs), dtype=np.float32)
        self.dones = np.zeros((capacity,num_envs), dtype=np.float32)
        self.values = np.zeros((capacity,num_envs), dtype=np.float32)
        self.log_probs = np.zeros((capacity,num_envs), dtype=np.float32)
        self.entropy = np.zeros((capacity,num_envs), dtype=np.float32)
        self.advantages = np.zeros((capacity,num_envs), dtype=np.float32)
        self.retuns = np.zeros((capacity,num_envs), dtype=np.float32) 

        self.reset()

    def push(self, state:np.ndarray, action, reward, done, value:torch.Tensor, log_prob:torch.Tensor, entropy):
        self.states[self.position] = state
        self.actions[self.position] = action
        self.rewards[self.position] = reward
        self.dones[self.position] = done
        self.values[self.position] = value.clone().cpu().numpy().flatten()
        self.log_probs[self.position] = log_prob.clone().cpu().numpy().flatten()
        self.entropy[self.position] = entropy

        self.position = (self.position + 1) % self.capacity
        self.size = min(self.size + 1, self.capacity)

    def reset(self):
        self.position = 0
        self.size = 0

    def compute_advantages_and_returns(self, last_value:torch.Tensor, dones):
        last_value = last_value.cpu().numpy().flatten()
        last_gae = 0
        for step in reversed(range(len(self.rewards))):
            if step == len(self.rewards) - 1:
                next_value = last_value
                next_non_terminal = 1 - dones
            else:
                next_value = self.values[step + 1]
                next_non_terminal = 1 - self.dones[step + 1]   
            
            delta = self.rewards[step] + self.gamma * next_value * next_non_terminal - self.values[step]
            last_gae = delta + self.gamma * self.gae_lambda * next_non_terminal * last_gae
            self.advantages[step]= last_gae

        self.returns = self.advantages + self.values

# %%
class A2C:
    def __init__(
        self,
        env: VecEnv,
        lr,  # learning rate
        gamma,  # discount factor
        gae_lambda,  # Generalized Advantage Estimation lambda
        max_steps,  # max steps for training
        n_steps,  # number of steps to run before updating
        device=torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    ):
        self.env = env
        self.num_envs = env.num_envs
        self.lr = lr
        self.gamma = gamma
        self.gae_lambda = gae_lambda
        self.max_steps = max_steps
        self.n_steps = n_steps
        self.device = device

        self.rollout_buffer = RolloutBuffer(
            env, n_steps, gamma, gae_lambda, device, num_envs=self.num_envs
        )

        if isinstance(env.observation_space, gym.spaces.Box):
            self.n_states = env.observation_space.shape[0]
        elif isinstance(env.observation_space, gym.spaces.Discrete):
            self.n_states = 1
        self.policy_net = PolicyNet(self.n_states, env.action_space.n, 64)
        self.optimizer_policy = AdamW(
            self.policy_net.parameters(), lr=self.lr, eps=1e-5
        )

        self.total_steps = 0

        self.last_state = self.env.reset()

        # stats
        self.episodes = 0
        self.total_rewards = np.zeros(self.env.num_envs)
        self.mean_episode_reward = 0

    def rollout(self):

        for _ in range(self.n_steps):

            with torch.no_grad():
                value, action, log_prob, entropy = self.policy_net(
                    torch.from_numpy(self.last_state).float().to(self.device)
                )

            next_state, rewards, dones, infos = self.env.step(action.detach().numpy())

            # check if done is because of truncation
            for idx, done in enumerate(dones):
                if (
                    done
                    and infos[idx].get("terminal_observation") is not None
                    and infos[idx].get("TimeLimit.truncated", False)
                ):
                    terminal_obs = infos[idx]["terminal_observation"]
                    with torch.no_grad():
                        terminal_value = self.policy_net.get_value(torch.tensor(terminal_obs).float().to(self.device))  # type: ignore[arg-type]
                    rewards[idx] += self.gamma * terminal_value

            self.rollout_buffer.push(
                self.last_state, action, rewards, done, value, log_prob, entropy
            )

            self.total_rewards += rewards
            self.total_steps += 1
            self.pbar.update(1)

            if dones[0]:
                self.episodes += 1
                if self.episodes % 100 == 0:

                    self.mean_episode_reward = (
                        self.total_rewards[0]
                    ) / self.episodes
                    self.pbar.set_description(
                        f"Reward: {self.mean_episode_reward :.3f} || Entropy: {entropy.mean():.3f}"
                    )
                    # self.writer.add_scalar("reward", self.total_rewards, self.episodes)
                    self.episodes = 0
                    self.total_rewards = np.zeros(self.env.num_envs)

            self.last_state = next_state

        with torch.no_grad():
            last_value = self.policy_net.get_value(
                torch.tensor(self.last_state).float().to(self.device)
            )

        self.rollout_buffer.compute_advantages_and_returns(last_value, dones)

    def learn(self):

        values, log_prob, entropy = self.policy_net.evaluate_actions(
            torch.tensor(self.rollout_buffer.states).float().to(self.device),
            torch.tensor(self.rollout_buffer.actions),
        )

        
        advantages = self.rollout_buffer.advantages
        # advantages = (advantages - advantages.mean())/ (advantages.std() + 1e-5)

        values = values.squeeze()

        self.policy_loss = -torch.mean(
          torch.from_numpy(advantages) * log_prob
        )

        self.entropy_loss = -torch.mean(entropy)
        self.value_loss = F.mse_loss(
            torch.from_numpy(self.rollout_buffer.returns), values
        )

        self.tot_policy_loss = (
            self.policy_loss + 0.5* self.value_loss + 0.0 * self.entropy_loss
        )

        if self.total_steps % 100 == 0:
            self.pbar.set_postfix(
                policy_loss=self.policy_loss.item(),
                value_loss=self.value_loss.item(),
                entropy_loss=self.entropy_loss.item(),
            )


        self.optimizer_policy.zero_grad()
        self.tot_policy_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 0.5)
        self.optimizer_policy.step()

    def train(self):
        self.pbar = tqdm(total=self.max_steps, position=0, leave=True)
        # self.writer = SummaryWriter(log_dir="runs/reinforce_logs/A2C")

        while self.total_steps < self.max_steps:
            self.rollout_buffer.reset()
            self.rollout()
            self.learn()

# %%
from stable_baselines3.common.env_util import make_vec_env

def make_env():
    env = gym.make("CartPole-v1")

    return env

# %%
env = make_vec_env(make_env, n_envs=8)

# %%
agent = A2C(
    env=env,
    lr=0.0007,
    gamma=0.99,
    gae_lambda=0.9,
    max_steps=200000,
    n_steps=5,
)

# %%
agent.train()
# Out:
# Reward: 436.975 || Entropy: 0.449:  74%|███████▍  | 147557/200000 [06:18<02:30, 347.38it/s, entropy_loss=-0.264, policy_loss=-0.0023, value_loss=9.48e-5]

# %%
import matplotlib.pyplot as plt

env = gym.make("FrozenLake-v1",is_slippery=False, render_mode='human')
            

n_episodes = 100
for _ in range(n_episodes):
    obs, info = env.reset()
    terminated = False
    truncated = False
    while not terminated and not truncated:
        with torch.no_grad():
            action = agent.policy_net(torch.tensor(obs).float().to(agent.device).view(1,-1), deterministic=True).item()
            obs, reward, terminated,  truncated, info = env.step(action)
            env.render()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[119], line 15
#      13 action = agent.policy_net(torch.tensor(obs).float().to(agent.device).view(1,-1), deterministic=True).item()
#      14 obs, reward, terminated,  truncated, info = env.step(action)
# ---> 15 env.render()
#
# File d:\anaconda3\envs\rl\Lib\site-packages\gymnasium\core.py:471, in Wrapper.render(self)
#     469 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     470     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 471     return self.env.render()
#
# File d:\anaconda3\envs\rl\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:70, in OrderEnforcing.render(self, *args, **kwargs)
#      65 if not self._disable_render_order_enforcing and not self._has_reset:
#      66     raise ResetNeeded(
#      67         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      68         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69     )
# ---> 70 return self.env.render(*args, **kwargs)
#
# File d:\anaconda3\envs\rl\Lib\site-packages\gymnasium\wrappers\env_checker.py:67, in PassiveEnvChecker.render(self, *args, **kwargs)
#      65     return env_render_passive_checker(self.env, *args, **kwargs)
#      66 else:
# ---> 67     return self.env.render(*args, **kwargs)
#
# File d:\anaconda3\envs\rl\Lib\site-packages\gymnasium\envs\toy_text\frozen_lake.py:338, in FrozenLakeEnv.render(self)
#     336     return self._render_text()
#     337 else:  # self.render_mode in {"human", "rgb_array"}:
# --> 338     return self._render_gui(self.render_mode)
#
# File d:\anaconda3\envs\rl\Lib\site-packages\gymnasium\envs\toy_text\frozen_lake.py:432, in FrozenLakeEnv._render_gui(self, mode)
#     430     pygame.event.pump()
#     431     pygame.display.update()
# --> 432     self.clock.tick(self.metadata["render_fps"])
#     433 elif mode == "rgb_array":
#     434     return np.transpose(
#     435         np.array(pygame.surfarray.pixels3d(self.window_surface)), axes=(1, 0, 2)
#     436     )
#
# KeyboardInterrupt:
